# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
from sklearn.metrics import *
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from keras.layers import Dropout
from keras import regularizers

# %%
df=pd.read_csv("processed.cleveland.csv")
df.head()
# Out:
#     age  sex  chest pain type  restingbps  cholestrol  fasting blood sugar  \
# 0  63.0  1.0              1.0       145.0       233.0                  1.0
# 1  67.0  1.0              4.0       160.0       286.0                  0.0
# 2  67.0  1.0              4.0       120.0       229.0                  0.0
# 3  37.0  1.0              3.0       130.0       250.0                  0.0
# 4  41.0  0.0              2.0       130.0       204.0                  0.0
#
#    restecg  maximum heart rate  exercise induced angina  \
# 0      2.0               150.0                      0.0
# 1      2.0               108.0                      1.0
# 2      2.0               129.0                      1.0
# 3      0.0               187.0                      0.0
# 4      2.0               172.0                      0.0
#
#    exercise ST depression  ST peak slope # of vessels colored by flourosopy  \
# 0                     2.3            3.0                                0.0
# 1                     1.5            2.0                                3.0
# 2                     2.6            2.0                                2.0
# 3                     3.5            3.0                                0.0
# 4                     1.4            1.0                                0.0
#
#   thal  heart disease
# 0  6.0              0
# 1  3.0              2
# 2  7.0              1
# 3  3.0              0
# 4  3.0              0

# %%
df = df[~df.isin(['?'])]
df = df.dropna(axis=0)

# %%
column_cont = ['age', 'chest pain type', 'restingbps', 'cholestrol', 'restecg', 'maximum heart rate', 'exercise ST depression', 'ST peak slope', '# of vessels colored by flourosopy', 'thal']
df[column_cont] = df[column_cont].astype(float)
df[column_cont] = df[column_cont].apply(lambda x: x/x.max())
df.head()
# Out:
#         age  sex  chest pain type  restingbps  cholestrol  \
# 0  0.818182  1.0             0.25       0.725    0.413121
# 1  0.870130  1.0             1.00       0.800    0.507092
# 2  0.870130  1.0             1.00       0.600    0.406028
# 3  0.480519  1.0             0.75       0.650    0.443262
# 4  0.532468  0.0             0.50       0.650    0.361702
#
#    fasting blood sugar  restecg  maximum heart rate  exercise induced angina  \
# 0                  1.0      1.0            0.742574                      0.0
# 1                  0.0      1.0            0.534653                      1.0
# 2                  0.0      1.0            0.638614                      1.0
# 3                  0.0      0.0            0.925743                      0.0
# 4                  0.0      1.0            0.851485                      0.0
#
#    exercise ST depression  ST peak slope  # of vessels colored by flourosopy  \
# 0                0.370968       1.000000                            0.000000
# 1                0.241935       0.666667                            1.000000
# 2                0.419355       0.666667                            0.666667
# 3                0.564516       1.000000                            0.000000
# 4                0.225806       0.333333                            0.000000
#
#        thal  heart disease
# 0  0.857143              0
# 1  0.428571              2
# 2  1.000000              1
# 3  0.428571              0
# 4  0.428571              0

# %%
y = df.pop('heart disease')
df.pop('# of vessels colored by flourosopy')
df.pop('restecg')
df.pop('exercise induced angina')
df.pop('exercise ST depression')
df.pop('ST peak slope')
df.pop('thal')
df.pop('cholestrol')
df.head()
# Out:
#         age  sex  chest pain type  restingbps  fasting blood sugar  \
# 0  0.818182  1.0             0.25       0.725                  1.0
# 1  0.870130  1.0             1.00       0.800                  0.0
# 2  0.870130  1.0             1.00       0.600                  0.0
# 3  0.480519  1.0             0.75       0.650                  0.0
# 4  0.532468  0.0             0.50       0.650                  0.0
#
#    maximum heart rate
# 0            0.742574
# 1            0.534653
# 2            0.638614
# 3            0.925743
# 4            0.851485

# %%
X = df
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, test_size=0.1, random_state=100)
y_train[y_train > 0] = 1
y_test[y_test > 0] = 1
y_train.head()
# Out:
# 265    1
# 267    1
# 15     0
# 252    0
# 291    0
# Name: heart disease, dtype: int64

# %%
# define a new keras model for binary classification
def create_binary_model():
    # create model
    model = Sequential()
    model.add(Dense(10, input_dim=6, kernel_initializer='normal',  kernel_regularizer=regularizers.l2(0.001),activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(6, kernel_initializer='normal',  kernel_regularizer=regularizers.l2(0.001),activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(1, activation='sigmoid'))
    
    # Compile model
    adam = Adam(lr=0.001)
    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model

binary_model = create_binary_model()

print(binary_model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 10)                70
#
#  dropout_8 (Dropout)         (None, 10)                0
#
#  dense_13 (Dense)            (None, 6)                 66
#
#  dropout_9 (Dropout)         (None, 6)                 0
#
#  dense_14 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 143
# Trainable params: 143
# Non-trainable params: 0
# _________________________________________________________________
# None
# C:\Users\Sid Kasi\AppData\Roaming\Python\Python310\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history=binary_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=10)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 1s 6ms/step - loss: 0.6934 - accuracy: 0.4719 - val_loss: 0.6928 - val_accuracy: 0.6000
# Epoch 2/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5356 - val_loss: 0.6922 - val_accuracy: 0.6000
# Epoch 3/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.5318 - val_loss: 0.6905 - val_accuracy: 0.6000
# Epoch 4/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5318 - val_loss: 0.6895 - val_accuracy: 0.6000
# Epoch 5/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6913 - accuracy: 0.5318 - val_loss: 0.6881 - val_accuracy: 0.6000
# Epoch 6/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6915 - accuracy: 0.5318 - val_loss: 0.6873 - val_accuracy: 0.6000
# Epoch 7/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6912 - accuracy: 0.5318 - val_loss: 0.6868 - val_accuracy: 0.6000
# Epoch 8/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6903 - accuracy: 0.5318 - val_loss: 0.6852 - val_accuracy: 0.6000
# Epoch 9/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6902 - accuracy: 0.5318 - val_loss: 0.6848 - val_accuracy: 0.6000
# Epoch 10/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6899 - accuracy: 0.5356 - val_loss: 0.6838 - val_accuracy: 0.6000
# Epoch 11/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6881 - accuracy: 0.5431 - val_loss: 0.6822 - val_accuracy: 0.6000
# Epoch 12/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6865 - accuracy: 0.5543 - val_loss: 0.6823 - val_accuracy: 0.6333
# Epoch 13/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6854 - accuracy: 0.6180 - val_loss: 0.6797 - val_accuracy: 0.6333
# Epoch 14/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6820 - accuracy: 0.6142 - val_loss: 0.6769 - val_accuracy: 0.6000
# Epoch 15/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6813 - accuracy: 0.6067 - val_loss: 0.6762 - val_accuracy: 0.6667
# Epoch 16/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6814 - accuracy: 0.6330 - val_loss: 0.6743 - val_accuracy: 0.7000
# Epoch 17/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6797 - accuracy: 0.6330 - val_loss: 0.6712 - val_accuracy: 0.6333
# Epoch 18/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6793 - accuracy: 0.6667 - val_loss: 0.6702 - val_accuracy: 0.7333
# Epoch 19/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6798 - accuracy: 0.5880 - val_loss: 0.6667 - val_accuracy: 0.6333
# Epoch 20/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6731 - accuracy: 0.6592 - val_loss: 0.6657 - val_accuracy: 0.7667
# Epoch 21/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6746 - accuracy: 0.6180 - val_loss: 0.6623 - val_accuracy: 0.7333
# Epoch 22/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6714 - accuracy: 0.6217 - val_loss: 0.6605 - val_accuracy: 0.7667
# Epoch 23/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6674 - accuracy: 0.6479 - val_loss: 0.6589 - val_accuracy: 0.7333
# Epoch 24/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6639 - accuracy: 0.6330 - val_loss: 0.6543 - val_accuracy: 0.7333
# Epoch 25/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6613 - accuracy: 0.6742 - val_loss: 0.6529 - val_accuracy: 0.7667
# Epoch 26/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6693 - accuracy: 0.6067 - val_loss: 0.6518 - val_accuracy: 0.7333
# Epoch 27/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6585 - accuracy: 0.6667 - val_loss: 0.6486 - val_accuracy: 0.7333
# Epoch 28/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6519 - accuracy: 0.6779 - val_loss: 0.6460 - val_accuracy: 0.7333
# Epoch 29/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6459 - accuracy: 0.6592 - val_loss: 0.6446 - val_accuracy: 0.7667
# Epoch 30/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6408 - accuracy: 0.6779 - val_loss: 0.6407 - val_accuracy: 0.7667
# Epoch 31/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6505 - accuracy: 0.6330 - val_loss: 0.6368 - val_accuracy: 0.7667
# Epoch 32/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6374 - accuracy: 0.6854 - val_loss: 0.6361 - val_accuracy: 0.7667
# Epoch 33/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6514 - accuracy: 0.6067 - val_loss: 0.6340 - val_accuracy: 0.7667
# Epoch 34/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6375 - accuracy: 0.6704 - val_loss: 0.6300 - val_accuracy: 0.7667
# Epoch 35/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6359 - accuracy: 0.6629 - val_loss: 0.6293 - val_accuracy: 0.7333
# Epoch 36/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6334 - accuracy: 0.6629 - val_loss: 0.6214 - val_accuracy: 0.7667
# Epoch 37/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6355 - accuracy: 0.6442 - val_loss: 0.6243 - val_accuracy: 0.7333
# Epoch 38/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6340 - accuracy: 0.6479 - val_loss: 0.6199 - val_accuracy: 0.7667
# Epoch 39/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6425 - accuracy: 0.6554 - val_loss: 0.6184 - val_accuracy: 0.7667
# Epoch 40/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6313 - accuracy: 0.6779 - val_loss: 0.6181 - val_accuracy: 0.7667
# Epoch 41/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6447 - accuracy: 0.5993 - val_loss: 0.6142 - val_accuracy: 0.7667
# Epoch 42/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6261 - accuracy: 0.6816 - val_loss: 0.6148 - val_accuracy: 0.7667
# Epoch 43/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6308 - accuracy: 0.6367 - val_loss: 0.6080 - val_accuracy: 0.7667
# Epoch 44/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6399 - accuracy: 0.6517 - val_loss: 0.6076 - val_accuracy: 0.7667
# Epoch 45/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6213 - accuracy: 0.6592 - val_loss: 0.6076 - val_accuracy: 0.7667
# Epoch 46/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6254 - accuracy: 0.6479 - val_loss: 0.6030 - val_accuracy: 0.7667
# Epoch 47/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6314 - accuracy: 0.6442 - val_loss: 0.6021 - val_accuracy: 0.7667
# Epoch 48/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6102 - accuracy: 0.6592 - val_loss: 0.5987 - val_accuracy: 0.7667
# Epoch 49/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6123 - accuracy: 0.6816 - val_loss: 0.6016 - val_accuracy: 0.7667
# Epoch 50/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6121 - accuracy: 0.6742 - val_loss: 0.5937 - val_accuracy: 0.7667

# %%
# generate classification report using predictions for binary model
from sklearn.metrics import classification_report, accuracy_score
# generate classification report using predictions for binary model 
binary_pred = np.round(binary_model.predict(X_test)).astype(int)

print('Results for Cleveland nerual network without fluroscopy')
print(accuracy_score(y_test, binary_pred))
print(classification_report(y_test, binary_pred))
# Out:
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000202B38145E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Results for Cleveland nerual network without fluroscopy
# 0.7666666666666667
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80        18
#            1       0.69      0.75      0.72        12
#
#     accuracy                           0.77        30
#    macro avg       0.76      0.76      0.76        30
# weighted avg       0.77      0.77      0.77        30

# %%
cm = confusion_matrix(y_test, binary_pred)

plt.figure(figsize=(7,5))

ax = sns.heatmap(cm/np.sum(cm),fmt='.2%', annot=True, cmap='Blues')

ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

ax.xaxis.set_ticklabels(['No HeartDisease','HeartDisease'])
ax.yaxis.set_ticklabels(['No HeartDisease','HeartDisease'])

print('Results for Cleveland nerual network with fluroscopy')
plt.show()
# Out:
# Results for Cleveland nerual network with fluroscopy

# %%
X_test.iloc[21:22]
# Out:
#           age  sex  chest pain type  restingbps  fasting blood sugar  \
# 240  0.532468  1.0              0.5        0.55                  0.0
#
#      maximum heart rate
# 240            0.757426
